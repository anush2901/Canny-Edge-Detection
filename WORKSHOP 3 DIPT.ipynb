# %% [markdown]
# ## WORKSHOP 3
# **NAME:** ANUSHMALIKA R
# **REG NO:** 212224230020

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread('parrot.jpg')

# %%
plt.imshow(image[:,:,::-1])
plt.title('Original Image')
plt.show()

# %%
medium=np.median(image)

# %%
low=int(max(0,0.7*medium))
high=int(max(255,1/3*medium))

# %%
blurred_gray = cv2.blur(gray_image, (7, 7))

# %%
plt.subplot(1, 2, 2)
plt.imshow(blurred_gray, cmap='gray')
plt.title(' Blurred')
plt.axis('off')

plt.show()

# %%
edges = cv2.Canny(gray_image, 150, 200)

# %%
plt.imshow(edges, cmap='gray')
plt.title('Canny Edge Detection')
plt.axis('off')

plt.show()
